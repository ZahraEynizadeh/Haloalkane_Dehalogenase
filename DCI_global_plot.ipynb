# %%
import numpy as np
     ...: import matplotlib.pyplot as plt

     ...: plt.subplots(figsize=(18, 10), dpi=100)

     ...: 
     ...: dci_values1 = np.load('absolute_dci_1cv2.npy')
     ...: dci_values2 = np.load('absolute_dci_2qvb.npy')
     ...: dci_values3 = np.load('absolute_dci_7pw1.npy')



     ...: 
     ...: plt.plot(dci_values1, label='DCI LinB')
     ...: 
     ...:
     ...: plt.plot(dci_values2, label='DCI DmbA')
     ...: 
     ...: 
     ...: plt.plot(dci_values3, label='DCI Ancestor')
     ...: 

     ...: 
     ...: 
     ...: plt.legend()



for i, value_tuple in enumerate(dci_values1):
      ax.plot(i+4, dci_values1[i], marker='o', linestyle='')
for i, value_tuple in enumerate(dci_values1):
      ax.plot(i+4, dci_values1[i], marker='o', linestyle='')
for i, value_tuple in enumerate(dci_values1):
      ax.plot(i+4, dci_values1[i], marker='o', linestyle='')

    
x = np.linspace(0, 10, 20)
plt.xticks(np.arange(min(x), max(x)+300, 10))

y = np.linspace(-10, 10, 100)
plt.yticks(np.arange(min(y), max(y), 1))
     ...: 
     ...: plt.xlabel('Index')
     ...: plt.ylabel('DCI Value')
     ...: plt.title('Dynamic Coupling Index (DCI) Values')
     ...: 
     ...: 
     ...: plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 30
#      25 plt.legend()
#      29 for i, value_tuple in enumerate(dci_values1):
# ---> 30       ax.plot(i+4, dci_values1[i], marker='o', linestyle='')
#      31 for i, value_tuple in enumerate(dci_values1):
#      32       ax.plot(i+4, dci_values1[i], marker='o', linestyle='')
#
# NameError: name 'ax' is not defined
